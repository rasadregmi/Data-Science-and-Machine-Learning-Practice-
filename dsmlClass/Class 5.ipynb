# %%
#Natural Language Processing

# %%
#Create a text file
text=open("randomDataNLP.txt")
text=text.read()
print(text)
# Out:
# Sign language is a visual language that enables individuals with hearing or speech impairments
# to communicate effectively. Nepali Sign Language (NSL), used widely in Nepal, is an essential
# means of communication for the deaf community. However, due to a lack of awareness and
# resources, NSL is not widely understood by the general population, leading to communication
# barriers.
#
# This project aims to develop a system that translates static gestures from Nepali Sign Language
# into text. By leveraging machine learning and computer vision techniques, the system processes
# hand gestures captured through a webcam and recognizes them using a trained model. The
# primary focus is on static gestures representing Nepali alphabets and selected common words.
# This tool seeks to promote inclusivity and accessibility, bridging the communication gap between
# the deaf community and the general population.

# %%
pip install nltk
# Out:
# Requirement already satisfied: nltk in c:\users\rasad regmi\anaconda3\envs\newone\lib\site-packages (3.9.1)
# Requirement already satisfied: click in c:\users\rasad regmi\anaconda3\envs\newone\lib\site-packages (from nltk) (8.1.7)
# Requirement already satisfied: joblib in c:\users\rasad regmi\anaconda3\envs\newone\lib\site-packages (from nltk) (1.4.2)
# Requirement already satisfied: regex>=2021.8.3 in c:\users\rasad regmi\anaconda3\envs\newone\lib\site-packages (from nltk) (2024.11.6)
# Requirement already satisfied: tqdm in c:\users\rasad regmi\anaconda3\envs\newone\lib\site-packages (from nltk) (4.67.1)
# Requirement already satisfied: colorama in c:\users\rasad regmi\anaconda3\envs\newone\lib\site-packages (from click->nltk) (0.4.6)
# Note: you may need to restart the kernel to use updated packages.

# %%
import nltk
from nltk import sent_tokenize
from nltk import word_tokenize

# %%
nltk.download('punkt_tab')
# Out:
# [nltk_data] Downloading package punkt_tab to C:\Users\Rasad
# [nltk_data]     Regmi\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
# True

# %%
sentences=sent_tokenize(text)
sentences
# Out:
# ['Sign language is a visual language that enables individuals with hearing or speech impairments\nto communicate effectively.',
#  'Nepali Sign Language (NSL), used widely in Nepal, is an essential\nmeans of communication for the deaf community.',
#  'However, due to a lack of awareness and\nresources, NSL is not widely understood by the general population, leading to communication\nbarriers.',
#  'This project aims to develop a system that translates static gestures from Nepali Sign Language\ninto text.',
#  'By leveraging machine learning and computer vision techniques, the system processes\nhand gestures captured through a webcam and recognizes them using a trained model.',
#  'The\nprimary focus is on static gestures representing Nepali alphabets and selected common words.',
#  'This tool seeks to promote inclusivity and accessibility, bridging the communication gap between\nthe deaf community and the general population.']

# %%
words=word_tokenize(text)
print(words)
# Out:
# ['Sign', 'language', 'is', 'a', 'visual', 'language', 'that', 'enables', 'individuals', 'with', 'hearing', 'or', 'speech', 'impairments', 'to', 'communicate', 'effectively', '.', 'Nepali', 'Sign', 'Language', '(', 'NSL', ')', ',', 'used', 'widely', 'in', 'Nepal', ',', 'is', 'an', 'essential', 'means', 'of', 'communication', 'for', 'the', 'deaf', 'community', '.', 'However', ',', 'due', 'to', 'a', 'lack', 'of', 'awareness', 'and', 'resources', ',', 'NSL', 'is', 'not', 'widely', 'understood', 'by', 'the', 'general', 'population', ',', 'leading', 'to', 'communication', 'barriers', '.', 'This', 'project', 'aims', 'to', 'develop', 'a', 'system', 'that', 'translates', 'static', 'gestures', 'from', 'Nepali', 'Sign', 'Language', 'into', 'text', '.', 'By', 'leveraging', 'machine', 'learning', 'and', 'computer', 'vision', 'techniques', ',', 'the', 'system', 'processes', 'hand', 'gestures', 'captured', 'through', 'a', 'webcam', 'and', 'recognizes', 'them', 'using', 'a', 'trained', 'model', '.', 'The', 'primary', 'focus', 'is', 'on', 'static', 'gestures', 'representing', 'Nepali', 'alphabets', 'and', 'selected', 'common', 'words', '.', 'This', 'tool', 'seeks', 'to', 'promote', 'inclusivity', 'and', 'accessibility', ',', 'bridging', 'the', 'communication', 'gap', 'between', 'the', 'deaf', 'community', 'and', 'the', 'general', 'population', '.']

# %%
from nltk.probability import FreqDist
fdist=FreqDist(words)
fdist.most_common(10)
# Out:
# [('.', 7),
#  (',', 7),
#  ('the', 6),
#  ('and', 6),
#  ('a', 5),
#  ('to', 5),
#  ('is', 4),
#  ('Sign', 3),
#  ('Nepali', 3),
#  ('communication', 3)]

# %%
import matplotlib.pyplot as plt
fdist.plot(10)
# Out:
# <Axes: xlabel='Samples', ylabel='Counts'>

# %%
words_nopunc=[]
for w in words:
    if w.isalpha():
        words_nopunc.append(w.lower())
print(words_nopunc)
# Out:
# ['sign', 'language', 'is', 'a', 'visual', 'language', 'that', 'enables', 'individuals', 'with', 'hearing', 'or', 'speech', 'impairments', 'to', 'communicate', 'effectively', 'nepali', 'sign', 'language', 'nsl', 'used', 'widely', 'in', 'nepal', 'is', 'an', 'essential', 'means', 'of', 'communication', 'for', 'the', 'deaf', 'community', 'however', 'due', 'to', 'a', 'lack', 'of', 'awareness', 'and', 'resources', 'nsl', 'is', 'not', 'widely', 'understood', 'by', 'the', 'general', 'population', 'leading', 'to', 'communication', 'barriers', 'this', 'project', 'aims', 'to', 'develop', 'a', 'system', 'that', 'translates', 'static', 'gestures', 'from', 'nepali', 'sign', 'language', 'into', 'text', 'by', 'leveraging', 'machine', 'learning', 'and', 'computer', 'vision', 'techniques', 'the', 'system', 'processes', 'hand', 'gestures', 'captured', 'through', 'a', 'webcam', 'and', 'recognizes', 'them', 'using', 'a', 'trained', 'model', 'the', 'primary', 'focus', 'is', 'on', 'static', 'gestures', 'representing', 'nepali', 'alphabets', 'and', 'selected', 'common', 'words', 'this', 'tool', 'seeks', 'to', 'promote', 'inclusivity', 'and', 'accessibility', 'bridging', 'the', 'communication', 'gap', 'between', 'the', 'deaf', 'community', 'and', 'the', 'general', 'population']

# %%
fdist=FreqDist(words_nopunc)
fdist.most_common(10)
# Out:
# [('the', 7),
#  ('and', 6),
#  ('a', 5),
#  ('to', 5),
#  ('language', 4),
#  ('is', 4),
#  ('sign', 3),
#  ('nepali', 3),
#  ('communication', 3),
#  ('gestures', 3)]

# %%
fdist.plot(10)
# Out:
# <Axes: xlabel='Samples', ylabel='Counts'>

# %%
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to C:\Users\Rasad
# [nltk_data]     Regmi\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
from nltk.corpus import stopwords
stopwords=stopwords.words('english')
print(stopwords)
# Out:
# ['i', 'me', 'my', 'myself', 'we', 'our', 'ours', 'ourselves', 'you', "you're", "you've", "you'll", "you'd", 'your', 'yours', 'yourself', 'yourselves', 'he', 'him', 'his', 'himself', 'she', "she's", 'her', 'hers', 'herself', 'it', "it's", 'its', 'itself', 'they', 'them', 'their', 'theirs', 'themselves', 'what', 'which', 'who', 'whom', 'this', 'that', "that'll", 'these', 'those', 'am', 'is', 'are', 'was', 'were', 'be', 'been', 'being', 'have', 'has', 'had', 'having', 'do', 'does', 'did', 'doing', 'a', 'an', 'the', 'and', 'but', 'if', 'or', 'because', 'as', 'until', 'while', 'of', 'at', 'by', 'for', 'with', 'about', 'against', 'between', 'into', 'through', 'during', 'before', 'after', 'above', 'below', 'to', 'from', 'up', 'down', 'in', 'out', 'on', 'off', 'over', 'under', 'again', 'further', 'then', 'once', 'here', 'there', 'when', 'where', 'why', 'how', 'all', 'any', 'both', 'each', 'few', 'more', 'most', 'other', 'some', 'such', 'no', 'nor', 'not', 'only', 'own', 'same', 'so', 'than', 'too', 'very', 's', 't', 'can', 'will', 'just', 'don', "don't", 'should', "should've", 'now', 'd', 'll', 'm', 'o', 're', 've', 'y', 'ain', 'aren', "aren't", 'couldn', "couldn't", 'didn', "didn't", 'doesn', "doesn't", 'hadn', "hadn't", 'hasn', "hasn't", 'haven', "haven't", 'isn', "isn't", 'ma', 'mightn', "mightn't", 'mustn', "mustn't", 'needn', "needn't", 'shan', "shan't", 'shouldn', "shouldn't", 'wasn', "wasn't", 'weren', "weren't", 'won', "won't", 'wouldn', "wouldn't"]

# %%
words_clean=[]
for w in words_nopunc:
    if w not in stopwords:
        words_clean.append(w)
print(words_clean)
# Out:
# ['sign', 'language', 'visual', 'language', 'enables', 'individuals', 'hearing', 'speech', 'impairments', 'communicate', 'effectively', 'nepali', 'sign', 'language', 'nsl', 'used', 'widely', 'nepal', 'essential', 'means', 'communication', 'deaf', 'community', 'however', 'due', 'lack', 'awareness', 'resources', 'nsl', 'widely', 'understood', 'general', 'population', 'leading', 'communication', 'barriers', 'project', 'aims', 'develop', 'system', 'translates', 'static', 'gestures', 'nepali', 'sign', 'language', 'text', 'leveraging', 'machine', 'learning', 'computer', 'vision', 'techniques', 'system', 'processes', 'hand', 'gestures', 'captured', 'webcam', 'recognizes', 'using', 'trained', 'model', 'primary', 'focus', 'static', 'gestures', 'representing', 'nepali', 'alphabets', 'selected', 'common', 'words', 'tool', 'seeks', 'promote', 'inclusivity', 'accessibility', 'bridging', 'communication', 'gap', 'deaf', 'community', 'general', 'population']

# %%
fdist=FreqDist(words_clean)
fdist.most_common(10)
# Out:
# [('language', 4),
#  ('sign', 3),
#  ('nepali', 3),
#  ('communication', 3),
#  ('gestures', 3),
#  ('nsl', 2),
#  ('widely', 2),
#  ('deaf', 2),
#  ('community', 2),
#  ('general', 2)]

# %%
fdist.plot(10)
# Out:
# <Axes: xlabel='Samples', ylabel='Counts'>

# %%
pip install wordcloud
# Out:
# Collecting wordcloud
#   Downloading wordcloud-1.9.4-cp38-cp38-win_amd64.whl.metadata (3.5 kB)
# Requirement already satisfied: numpy>=1.6.1 in c:\users\rasad regmi\anaconda3\envs\newone\lib\site-packages (from wordcloud) (1.24.4)
# Requirement already satisfied: pillow in c:\users\rasad regmi\anaconda3\envs\newone\lib\site-packages (from wordcloud) (10.4.0)
# Requirement already satisfied: matplotlib in c:\users\rasad regmi\anaconda3\envs\newone\lib\site-packages (from wordcloud) (3.7.5)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\rasad regmi\anaconda3\envs\newone\lib\site-packages (from matplotlib->wordcloud) (1.1.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\rasad regmi\anaconda3\envs\newone\lib\site-packages (from matplotlib->wordcloud) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\rasad regmi\anaconda3\envs\newone\lib\site-packages (from matplotlib->wordcloud) (4.55.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\rasad regmi\anaconda3\envs\newone\lib\site-packages (from matplotlib->wordcloud) (1.4.7)
# Requirement already satisfied: packaging>=20.0 in c:\users\rasad regmi\anaconda3\envs\newone\lib\site-packages (from matplotlib->wordcloud) (24.2)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\rasad regmi\anaconda3\envs\newone\lib\site-packages (from matplotlib->wordcloud) (3.1.4)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\rasad regmi\anaconda3\envs\newone\lib\site-packages (from matplotlib->wordcloud) (2.9.0)
# Requirement already satisfied: importlib-resources>=3.2.0 in c:\users\rasad regmi\anaconda3\envs\newone\lib\site-packages (from matplotlib->wordcloud) (6.4.5)
# Requirement already satisfied: zipp>=3.1.0 in c:\users\rasad regmi\anaconda3\envs\newone\lib\site-packages (from importlib-resources>=3.2.0->matplotlib->wordcloud) (3.20.2)
# Requirement already satisfied: six>=1.5 in c:\users\rasad regmi\anaconda3\envs\newone\lib\site-packages (from python-dateutil>=2.7->matplotlib->wordcloud) (1.16.0)
# Downloading wordcloud-1.9.4-cp38-cp38-win_amd64.whl (300 kB)
# Installing collected packages: wordcloud
# Successfully installed wordcloud-1.9.4
# Note: you may need to restart the kernel to use updated packages.

# %%
from wordcloud import WordCloud
wordcloud=WordCloud().generate(text)
plt.figure(figsize=(12,12))
plt.imshow(wordcloud)
plt.axis("off")
plt.show()
